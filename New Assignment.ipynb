# %% [markdown]
# I would like to compare between New York and Toronto and decide which location would be a better location to set up a restaurant

# %%
The data sets i would be using would be the Foursquare location data where the i would look at specifically the kind of restaurants set upw
